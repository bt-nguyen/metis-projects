# %%
###############
### IMPORTS ###
###############

import pandas as pd
import numpy as np

# %% [markdown]
# The original dataset can be found at: https://www.kaggle.com/rounakbanik/the-movies-dataset
#
# These files were too large to upload onto GitHub so they had to be deleted. When downloading the flatfiles, please place them in 'brian_nguyen/data/' path to read in the CSV.

# %% [markdown]
# ### Read in CSV files as data frames

# %%
df_movies = pd.read_csv('data/movies_metadata.csv')
print('Length of df_movies: ', len(df_movies))
print('Columns: ', df_movies.columns)
df_movies.sample(5)
# Out:
# Length of df_movies:  45466
# Columns:  Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#        adult                              belongs_to_collection    budget  \
# 9093   False  {'id': 362047, 'name': 'Bikini Summer Collecti...         0
# 34566  False                                                NaN         0
# ...

# %%
df_credits = pd.read_csv('data/credits.csv')
print('Length of df_credits: ', len(df_credits))
df_credits.sample(5)
# Out:
# Length of df_credits:  45476
#                                                     cast  \
# 7228   [{'cast_id': 15, 'character': 'Jimmy', 'credit...
# 15706  [{'cast_id': 2, 'character': 'Jack / Edward', ...
# 4726   [{'cast_id': 1, 'character': 'Narrator (voice)...
# 28718  [{'cast_id': 1, 'character': 'Perry Mason', 'c...
# 10097  [{'cast_id': 2, 'character': "Wilhelmina 'Wil'...
#
#                                                     crew      id
# 7228   [{'credit_id': '55377e8f9251414ab9001c4c', 'de...    2122
# 15706  [{'credit_id': '52fe4555c3a368484e0542fb', 'de...   27579
# 4726   [{'credit_id': '52fe46669251416c750770dd', 'de...   15559
# 28718  [{'credit_id': '52fe4bca9251416c7510e09b', 'de...  148410
# 10097  [{'credit_id': '5686e2ddc3a3683628008212', 'de...   19316

# %%
df_keywords = pd.read_csv('data/keywords.csv')
print('Length of df_keywords: ', len(df_keywords))
df_keywords.sample(5)
# Out:
# Length of df_keywords:  46419
#            id                                           keywords
# 24698  290729                                                 []
# 20673  119634                                                 []
# 32514  192431         [{'id': 187056, 'name': 'woman director'}]
# 26329   44921  [{'id': 4616, 'name': 'apache'}, {'id': 160522...
# 13229   16268  [{'id': 3386, 'name': 'space war'}, {'id': 456...

# %%
df_links = pd.read_csv('data/links.csv')
print('Length of df_keywords: ', len(df_keywords))
df_links.sample(5)
# Out:
# Length of df_keywords:  46419
#        movieId   imdbId    tmdbId
# 16927    85342  1555149   47931.0
# 18874    93563  1592525   81796.0
# 31515   137184   403056  117343.0
# 16705    84232    14218   51367.0
# 9634     31035    86429   21259.0

# %%
# Rename 'movieId' to 'id' to match column names
df_links = df_links.rename(columns={'movieId': 'id'})
df_links.sample(5)
# Out:
#            id   imdbId    tmdbId
# 17952   89778  1608285   85821.0
# 18106   90419  1182924   18916.0
# 35438  148636   498719   85304.0
# 39022  158687  3449302  299730.0
# 41097  164594   129994  117592.0

# %% [markdown]
# ### Merge dataframe

# %%
print('Datatype of df_movies[id]', type(df_movies['id'].loc[1]))
print('Datatype of df_credits[id]', type(df_credits['id'].loc[1]))
print('Datatype of df_keywords[id]', type(df_keywords['id'].loc[1]))
print('Datatype of df_links[id]', type(df_links['id'].loc[1]))
# Out:
# Datatype of df_movies[id] <class 'str'>
# Datatype of df_credits[id] <class 'numpy.int64'>
# Datatype of df_keywords[id] <class 'numpy.int64'>
# Datatype of df_links[id] <class 'numpy.int64'>

# %%
# Change all ['id'] columns to str (from int64)
# This lets me keep the rows that cannot be converted to int64
df_credits['id'] = df_credits['id'].astype(str)
df_keywords['id'] = df_keywords['id'].astype(str)
df_links['id'] = df_links['id'].astype(str)

# %%
print('Datatype of df_movies[id]', type(df_movies['id'].loc[1]))
print('Datatype of df_credits[id]', type(df_credits['id'].loc[1]))
print('Datatype of df_keywords[id]', type(df_keywords['id'].loc[1]))
print('Datatype of dflinks[id]', type(df_links['id'].loc[1]))
# Out:
# Datatype of df_movies[id] <class 'str'>
# Datatype of df_credits[id] <class 'str'>
# Datatype of df_keywords[id] <class 'str'>
# Datatype of dflinks[id] <class 'str'>

# %%
df_temp1 = df_movies.merge(df_credits, how='inner', on='id')

# %%
df_temp1.head(3)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
#
#      original_title                                           overview  ...  \
# 0         Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
# ...

# %%
df = df_temp1.merge(df_keywords, how='inner', on='id')

# %%
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 46623  False                                                NaN         0
# 46624  False                                                NaN         0
# 46625  False                                                NaN         0
# 46626  False                                                NaN         0
# 46627  False                                                NaN         0
#
#                                                   genres  \
# ...

# %% [markdown]
# ### Functions to Obtain Clean Director, Cast, and Keywords

# %%
from ast import literal_eval

features = ['cast', 'crew', 'keywords', 'genres']
for feature in features:
    df[feature] = df[feature].apply(literal_eval)

# %%
# Get the director's name from the crew feature. If director is not listed, return NaN
def get_director(x):
    for i in x:
        if i['job'] == 'Director':
            return i['name']
    return np.nan

# %%
# Returns the list top 3 elements or entire list; whichever is more.
def get_list(x):
    if isinstance(x, list):
        names = [i['name'] for i in x]
        #Check if more than 3 elements exist. If yes, return only first three. If no, return entire list.
        if len(names) > 5:
            names = names[:5]
        return names

    #Return empty list in case of missing/malformed data
    return []

# %%
# Define new director, cast, genres and keywords features that are in a suitable form.
df['director'] = df['crew'].apply(get_director)

features = ['cast', 'keywords', 'genres']
for feature in features:
    df[feature] = df[feature].apply(get_list)

# %%
df[['title', 'cast', 'director', 'keywords', 'genres']].head(3)
# Out:
#               title                                               cast  \
# 0         Toy Story  [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...
# 1           Jumanji  [Robin Williams, Jonathan Hyde, Kirsten Dunst,...
# 2  Grumpier Old Men  [Walter Matthau, Jack Lemmon, Ann-Margret, Sop...
#
#         director                                           keywords  \
# 0  John Lasseter          [jealousy, toy, boy, friendship, friends]
# 1   Joe Johnston  [board game, disappearance, based on children'...
# 2  Howard Deutch  [fishing, best friend, duringcreditsstinger, o...
#
#                          genres
# 0   [Animation, Comedy, Family]
# 1  [Adventure, Fantasy, Family]
# 2             [Romance, Comedy]

# %%
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 46623  False                                                NaN         0
# 46624  False                                                NaN         0
# 46625  False                                                NaN         0
# 46626  False                                                NaN         0
# 46627  False                                                NaN         0
#
#                              genres                              homepage  \
# ...

# %%
# Export merged dataframe
df.to_csv('data/dataframe_merged.csv', index=False)
